# %% [markdown]
# ### LAB - S03-L012-LAB-Metody isin, isnull, notnull, between
# 1. Zaimportuj moduł pandas oraz numpy i nadaj im standardowe aliasy. Do zmiennej fuel wczytaj zawartośćpliku fuel.csv. Podczas wczytywania skorzystaj z dodatkowego argumentu low_memory=False, pobierztylko następujące kolumny: 'Vehicle ID','Year','Make','Model','Class','Fuel Type','Combined MPG(FT1)','Start Stop Technology'. Wyświetl nagłówek tak utworzonego Data Frame2. Utwórz zmienną listOfCars typu lista i wpisz do niej napisy: 'Renault', 'Toyota','Ford'.
# 2. Utwórz zmiennąisInList i korzystając z metody pokazanej na lekcji przypisz do niej serię z wartościami True/False - True,jeżeli w kolumnie "Make" jest wartość z listy listOfCars, False - w przeciwnym razie. Wyświetl nagłówektej serii
# 3. Wyświetl z fuel, te samochody, które są na liście listOfCars. Wykorzystaj w tym celu zmienną isInList
# 4. Utwórz zmienną isNoStartStopDefined i korzystając z metody pokazanej na lekcji przypisz do niej serięz wartościami True/False - True, jeżeli w kolumnie "Start Stop Technology" jest wartość NaN, False - wprzeciwnym razie. Wyświetl nagłówek tej serii
# 5. Wyświetl z fuel te samochody, o których nie wiadomo czy mają system Start/Stop. Wykorzystaj w tymcelu zmienną isNoStartStopDefined
# 6. Utwórz zmienną isStartStopDefined i korzystając z metody pokazanej na lekcji przypisz do niej serię zwartościami True/False - True, jeżeli w kolumnie "Start Stop Technology" jest zdefiniowna jakaśwartość, False - w przeciwnym razie. Wyświetl nagłówek tej serii
# 7. Wyświetl z fuel te samochody, o których wiadomo czy mają system Start/Stop. Wykorzystaj w tym celuzmienną isStartStopDefined
# 8. Utwórz zmienną mpg50_60 i korzystając z metody pokazanej na lekcji przypisz do niej serię zwartościami True/False - True, jeżeli w kolumnie "Combined MPG (FT1)" jest wartość >=50 i <=60, False- w przeciwnym razie. Wyświetl nagłówek tej serii
# 9. Wyświetl z fuel te samochody, które na jednym galonie paliwa przejadą od 50-60 mil. Wykorzystaj w tymcelu zmienną mpg50_60
# 10. Korzystając ze zdefiniowanych wcześniej zmiennych wyświetl komunikat podobny do poniższego:
#         There are 4376 cars within the list ['Renault', 'Toyota', 'Ford']
#         There are 31374 cars where Start/Stop technology is not determined
#         There are 310 cars where Start/Stop technology is determined
#         There are 13 cares with MPG value between 50 and 60

# %%
import pandas as pd
import numpy as np

# %%
fuel = pd.read_csv('./course-files/fuel.csv', 
                   low_memory=False, 
                   usecols=['Vehicle ID','Year','Make','Model','Class','Fuel Type','Combined MPG (FT1)','Start Stop Technology'],
                   index_col='Vehicle ID')

# %%
fuel.head()
# Out:
#             Year        Make               Model                        Class  \
# Vehicle ID
# 26587       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 27705       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 26561       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27681       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27550       1984  AM General   DJ Po Vehicle 2WD  Special Purpose Vehicle 2WD
#
#            Fuel Type  Combined MPG (FT1) Start Stop Technology
# Vehicle ID
# 26587        Regular                20.0                   NaN
# 27705        Regular                20.0                   NaN
# 26561        Regular                21.0                   NaN
# 27681        Regular                21.0                   NaN
# 27550        Regular                17.0                   NaN

# %%
listOfCars = ['Renault', 'Toyota','Ford']

# %%
isInList = fuel['Make'].isin(listOfCars)

# %%
fuel.shape
# Out:
# (31684, 7)

# %%
isInList.head()
# Out:
# Vehicle ID
# 26587    False
# 27705    False
# 26561    False
# 27681    False
# 27550    False
# Name: Make, dtype: bool

# %%
fuel[isInList].head()
# Out:
#             Year  Make       Model                        Class Fuel Type  \
# Vehicle ID
# 27613       1984  Ford  Bronco 4WD  Special Purpose Vehicle 4WD   Regular
# 27616       1984  Ford  Bronco 4WD  Special Purpose Vehicle 4WD   Regular
# 27619       1984  Ford  Bronco 4WD  Special Purpose Vehicle 4WD   Regular
# 27622       1984  Ford  Bronco 4WD  Special Purpose Vehicle 4WD   Regular
# 28472       1984  Ford  Bronco 4WD  Special Purpose Vehicle 4WD   Regular
#
#             Combined MPG (FT1) Start Stop Technology
# Vehicle ID
# 27613                     13.0                   NaN
# 27616                     11.0                   NaN
# 27619                     10.0                   NaN
# 27622                     11.0                   NaN
# 28472                     13.0                   NaN

# %%
isNoStartStopDefined = fuel["Start Stop Technology"].isnull()

# %%
isNoStartStopDefined.head()
# Out:
# Vehicle ID
# 26587    True
# 27705    True
# 26561    True
# 27681    True
# 27550    True
# Name: Start Stop Technology, dtype: bool

# %%
fuel[isNoStartStopDefined].head()
# Out:
#             Year        Make               Model                        Class  \
# Vehicle ID
# 26587       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 27705       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 26561       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27681       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27550       1984  AM General   DJ Po Vehicle 2WD  Special Purpose Vehicle 2WD
#
#            Fuel Type  Combined MPG (FT1) Start Stop Technology
# Vehicle ID
# 26587        Regular                20.0                   NaN
# 27705        Regular                20.0                   NaN
# 26561        Regular                21.0                   NaN
# 27681        Regular                21.0                   NaN
# 27550        Regular                17.0                   NaN

# %%
isStartStopDefined = fuel["Start Stop Technology"].notnull()

# %%
fuel[isStartStopDefined].head()
# Out:
#             Year       Make                      Model  \
# Vehicle ID
# 30976       1998  Chevrolet               S10 Electric
# 30977       1998  Chevrolet               S10 Electric
# 30975       1998      Honda                    EV Plus
# 30973       1999      Dodge  Caravan/Grand Caravan 2WD
# 30971       1999       Ford          Ranger Pickup 2WD
#
#                                  Class    Fuel Type  Combined MPG (FT1)  \
# Vehicle ID
# 30976          Small Pickup Trucks 2WD  Electricity                55.0
# 30977          Small Pickup Trucks 2WD  Electricity                28.0
# 30975                     Compact Cars  Electricity                48.0
# 30973                    Minivan - 2WD  Electricity                35.0
# 30971       Standard Pickup Trucks 2WD  Electricity                58.0
#
#            Start Stop Technology
# Vehicle ID
# 30976                          N
# 30977                          N
# 30975                          N
# ...

# %%
mpg50_60 = fuel['Combined MPG (FT1)'].between(50,60)

# %%
mpg50_60.head()
# Out:
# Vehicle ID
# 26587    False
# 27705    False
# 26561    False
# 27681    False
# 27550    False
# Name: Combined MPG (FT1), dtype: bool

# %%
fuel[mpg50_60]
# Out:
#             Year       Make              Model                       Class  \
# Vehicle ID
# 30976       1998  Chevrolet       S10 Electric     Small Pickup Trucks 2WD
# 30971       1999       Ford  Ranger Pickup 2WD  Standard Pickup Trucks 2WD
# 30966       2000       Ford  Ranger Pickup 2WD  Standard Pickup Trucks 2WD
# 30967       2000       Ford  Ranger Pickup 2WD  Standard Pickup Trucks 2WD
# 15606       2000      Honda            Insight                 Two Seaters
# 30965       2001       Ford  Ranger Pickup 2WD  Standard Pickup Trucks 2WD
# 16447       2001      Honda            Insight                 Two Seaters
# 17355       2002      Honda            Insight                 Two Seaters
# 18313       2003      Honda            Insight                 Two Seaters
# 19357       2004      Honda            Insight                 Two Seaters
# 20479       2005      Honda            Insight                 Two Seaters
# ...

# %%
print("There are {} cars within the list: {}".format(len(fuel[isInList]), listOfCars))
print("There are {} cars where Start/Stop technology is not determined".format(len(fuel[isNoStartStopDefined])))
print("There are {} cars where Start/Stop technology is determined".format(len(fuel[isStartStopDefined])))
print("There are {} cares with MPG value between 50 and 60".format(len(fuel[mpg50_60])))
# Out:
# There are 4376 cars within the list: ['Renault', 'Toyota', 'Ford']
# There are 31374 cars where Start/Stop technology is not determined
# There are 310 cars where Start/Stop technology is determined
# There are 13 cares with MPG value between 50 and 60
