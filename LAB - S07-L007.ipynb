# %% [markdown]
# ### LAB - S07-L007 - opcje polecenia merge
# 1. Zaimportuj moduł pandas i numpy nadaj im standardowe aliasy
# 2. Do zmiennej suppliers zaimportuj zawartość pliku suppliers.csv. Pobierz tylko kolumny SupplierID,CompanyName, City
# 3. Do zmiennej products zaimportuj zawartość pliku products.csv". Pobierz tylko kolumny ProductID, ProductName, SupplierID
# 4. W kolejnych zadaniach będziesz łączyć ze sobą suppliers i products, a do połączenia wykorzystasz kolumnę SupplierID. Kolumna ta może delikatnie zmienić nazwę lub stać się indeksem. W zależności od tego musisz w odpowiedni sposób zmieniać parametry i wybierać odpowiednie polecenia:
# 5. Do data frame suppliers dołącz dane z products (tak jak to opisano powyżej)
# 6. W suppliers zdefiniuj SupplierID jako indeks (pamiętaj o parametrze inplace). Następnie do data frame suppliers dołącz dane z products
# 7. W products zdefiniuj SupplierID jako indeks (pamiętaj o parametrze inplace). Następnie do data frame suppliers dołącz dane z products
# 8. W suppliers zresetuj indeks (pamiętaj o parametrze inplace). Następnie do data frame suppliers dołącz dane z products
# 9. W products zresetuj indeks (pamiętaj o parametrze inplace), a potem zmień nazwę kolumny SupplierID na supplier_id. Następnie do data frame suppliers dołącz dane z products

# %%
import pandas as pd
import numpy as np

# %%
suppliers = pd.read_csv('./course-files/northwind-mongo-master/suppliers.csv', 
                        usecols=['SupplierID', 'CompanyName', 'City'])

# %%
products = pd.read_csv('./course-files/northwind-mongo-master/products_del_2.csv', 
                        usecols=['ProductID', 'ProductName', 'SupplierID'])

# %%
products.merge(right=suppliers, on='SupplierID')
# Out:
#     ProductID                      ProductName  SupplierID  \
# 0           1                             Chai           1
# 1           2                            Chang           1
# 2           6     Grandma's Boysenberry Spread           3
# 3           7  Uncle Bob's Organic Dried Pears           3
# 4           8       Northwoods Cranberry Sauce           3
# ..        ...                              ...         ...
# 63         55                     Pâté chinois          25
# 64         56           Gnocchi di nonna Alice          26
# 65         57                   Ravioli Angelo          26
# 66         60                Camembert Pierrot          28
# 67         61                   Sirop d'érable          29
#
#                   CompanyName           City
# 0              Exotic Liquids         London
# 1              Exotic Liquids         London
# 2   Grandma Kelly's Homestead      Ann Arbor
# 3   Grandma Kelly's Homestead      Ann Arbor
# 4   Grandma Kelly's Homestead      Ann Arbor
# ..                        ...            ...
# 63                  Ma Maison       Montréal
# 64       Pasta Buttini s.r.l.        Salerno
# 65       Pasta Buttini s.r.l.        Salerno
# 66               Gai pâturage         Annecy
# 67           Forêts d'érables  Ste-Hyacinthe
#
# [68 rows x 5 columns]

# %%
suppliers.merge(right=products, on='SupplierID').head()
# Out:
#    SupplierID                CompanyName       City  ProductID  \
# 0           1             Exotic Liquids     London          1
# 1           1             Exotic Liquids     London          2
# 2           3  Grandma Kelly's Homestead  Ann Arbor          6
# 3           3  Grandma Kelly's Homestead  Ann Arbor          7
# 4           3  Grandma Kelly's Homestead  Ann Arbor          8
#
#                        ProductName
# 0                             Chai
# 1                            Chang
# 2     Grandma's Boysenberry Spread
# 3  Uncle Bob's Organic Dried Pears
# 4       Northwoods Cranberry Sauce

# %%
suppliers.set_index('SupplierID', inplace=True)

# %%
suppliers.merge(right=products, left_index=True, right_on='SupplierID')
# Out:
#                   CompanyName           City  ProductID  \
# 0              Exotic Liquids         London          1
# 1              Exotic Liquids         London          2
# 2   Grandma Kelly's Homestead      Ann Arbor          6
# 3   Grandma Kelly's Homestead      Ann Arbor          7
# 4   Grandma Kelly's Homestead      Ann Arbor          8
# ..                        ...            ...        ...
# 51                  Ma Maison       Montréal         55
# 52       Pasta Buttini s.r.l.        Salerno         56
# 53       Pasta Buttini s.r.l.        Salerno         57
# 54               Gai pâturage         Annecy         60
# 55           Forêts d'érables  Ste-Hyacinthe         61
#
#                         ProductName  SupplierID
# 0                              Chai           1
# 1                             Chang           1
# 2      Grandma's Boysenberry Spread           3
# 3   Uncle Bob's Organic Dried Pears           3
# 4        Northwoods Cranberry Sauce           3
# ..                              ...         ...
# 51                     Pâté chinois          25
# 52           Gnocchi di nonna Alice          26
# 53                   Ravioli Angelo          26
# 54                Camembert Pierrot          28
# 55                   Sirop d'érable          29
#
# [68 rows x 5 columns]

# %%
products.set_index('SupplierID', inplace=True)

# %%
suppliers.merge(right=products, left_index=True, right_index=True)
# Out:
#                           CompanyName           City  ProductID  \
# SupplierID
# 1                      Exotic Liquids         London          1
# 1                      Exotic Liquids         London          2
# 3           Grandma Kelly's Homestead      Ann Arbor          6
# 3           Grandma Kelly's Homestead      Ann Arbor          7
# 3           Grandma Kelly's Homestead      Ann Arbor          8
# ...                               ...            ...        ...
# 25                          Ma Maison       Montréal         55
# 26               Pasta Buttini s.r.l.        Salerno         56
# 26               Pasta Buttini s.r.l.        Salerno         57
# 28                       Gai pâturage         Annecy         60
# 29                   Forêts d'érables  Ste-Hyacinthe         61
#
#                                 ProductName
# SupplierID
# 1                                      Chai
# 1                                     Chang
# 3              Grandma's Boysenberry Spread
# 3           Uncle Bob's Organic Dried Pears
# 3                Northwoods Cranberry Sauce
# ...                                     ...
# 25                             Pâté chinois
# 26                   Gnocchi di nonna Alice
# 26                           Ravioli Angelo
# 28                        Camembert Pierrot
# 29                           Sirop d'érable
#
# [68 rows x 4 columns]

# %%
suppliers.join(products)
# Out:
#                            CompanyName           City  ProductID  \
# SupplierID
# 1                       Exotic Liquids         London        1.0
# 1                       Exotic Liquids         London        2.0
# 2           New Orleans Cajun Delights    New Orleans        NaN
# 3            Grandma Kelly's Homestead      Ann Arbor        6.0
# 3            Grandma Kelly's Homestead      Ann Arbor        7.0
# ...                                ...            ...        ...
# 26                Pasta Buttini s.r.l.        Salerno       56.0
# 26                Pasta Buttini s.r.l.        Salerno       57.0
# 27                  Escargots Nouveaux       Montceau        NaN
# 28                        Gai pâturage         Annecy       60.0
# 29                    Forêts d'érables  Ste-Hyacinthe       61.0
#
#                                 ProductName
# SupplierID
# 1                                      Chai
# 1                                     Chang
# 2                                       NaN
# 3              Grandma's Boysenberry Spread
# 3           Uncle Bob's Organic Dried Pears
# ...                                     ...
# 26                   Gnocchi di nonna Alice
# 26                           Ravioli Angelo
# 27                                      NaN
# 28                        Camembert Pierrot
# 29                           Sirop d'érable
#
# [70 rows x 4 columns]

# %%
suppliers.reset_index()
# Out:
#     SupplierID                             CompanyName           City
# 0            1                          Exotic Liquids         London
# 1            2              New Orleans Cajun Delights    New Orleans
# 2            3               Grandma Kelly's Homestead      Ann Arbor
# 3            4                           Tokyo Traders          Tokyo
# 4            5      Cooperativa de Quesos 'Las Cabras'         Oviedo
# 5            6                                Mayumi's          Osaka
# 6            7                            Pavlova Ltd.      Melbourne
# 7            8                 Specialty Biscuits Ltd.     Manchester
# 8            9                        PB Knäckebröd AB       Göteborg
# 9           10               Refrescos Americanas LTDA      Sao Paulo
# 10          11             Heli Süßwaren GmbH & Co. KG         Berlin
# 11          12       Plutzer Lebensmittelgroßmärkte AG      Frankfurt
# 12          13  Nord-Ost-Fisch Handelsgesellschaft mbH       Cuxhaven
# 13          14                 Formaggi Fortini s.r.l.     75 Ravenna
# 14          15                         Norske Meierier       Sandvika
# 15          16                       Bigfoot Breweries           Bend
# 16          17                       Svensk Sjöföda AB      Stockholm
# 17          18              Aux joyeux ecclésiastiques          Paris
# 18          19             New England Seafood Cannery         Boston
# 19          20                            Leka Trading      Singapore
# 20          21                              Lyngbysild         Lyngby
# 21          22                     Zaanse Snoepfabriek        Zaandam
# 22          23                               Karkki Oy   Lappeenranta
# 23          24                              G'day Mate         Sydney
# 24          25                               Ma Maison       Montréal
# 25          26                    Pasta Buttini s.r.l.        Salerno
# 26          27                      Escargots Nouveaux       Montceau
# 27          28                            Gai pâturage         Annecy
# 28          29                        Forêts d'érables  Ste-Hyacinthe

# %%
suppliers.head()
# Out:
#                                    CompanyName         City
# SupplierID
# 1                               Exotic Liquids       London
# 2                   New Orleans Cajun Delights  New Orleans
# 3                    Grandma Kelly's Homestead    Ann Arbor
# 4                                Tokyo Traders        Tokyo
# 5           Cooperativa de Quesos 'Las Cabras'       Oviedo

# %%
suppliers.reset_index(inplace=True)

# %%
suppliers.head(3)
# Out:
#    SupplierID                 CompanyName         City
# 0           1              Exotic Liquids       London
# 1           2  New Orleans Cajun Delights  New Orleans
# 2           3   Grandma Kelly's Homestead    Ann Arbor

# %%
products.head(3)
# Out:
#             ProductID                   ProductName
# SupplierID
# 1                   1                          Chai
# 1                   2                         Chang
# 3                   6  Grandma's Boysenberry Spread

# %%
suppliers.merge(right=products, left_on='SupplierID', right_index=True)
# Out:
#     SupplierID                CompanyName           City  ProductID  \
# 0            1             Exotic Liquids         London          1
# 0            1             Exotic Liquids         London          2
# 2            3  Grandma Kelly's Homestead      Ann Arbor          6
# 2            3  Grandma Kelly's Homestead      Ann Arbor          7
# 2            3  Grandma Kelly's Homestead      Ann Arbor          8
# ..         ...                        ...            ...        ...
# 24          25                  Ma Maison       Montréal         55
# 25          26       Pasta Buttini s.r.l.        Salerno         56
# 25          26       Pasta Buttini s.r.l.        Salerno         57
# 27          28               Gai pâturage         Annecy         60
# 28          29           Forêts d'érables  Ste-Hyacinthe         61
#
#                         ProductName
# 0                              Chai
# 0                             Chang
# 2      Grandma's Boysenberry Spread
# 2   Uncle Bob's Organic Dried Pears
# 2        Northwoods Cranberry Sauce
# ..                              ...
# 24                     Pâté chinois
# 25           Gnocchi di nonna Alice
# 25                   Ravioli Angelo
# 27                Camembert Pierrot
# 28                   Sirop d'érable
#
# [68 rows x 5 columns]

# %%
products.reset_index(inplace=True)

# %%
products.rename({'SupplierID' : 'supplier_id' }, inplace=True, axis='columns')

# %%
products.head(3)
# Out:
#    supplier_id  ProductID                   ProductName
# 0            1          1                          Chai
# 1            1          2                         Chang
# 2            3          6  Grandma's Boysenberry Spread

# %%
suppliers.merge(right=products, left_on='SupplierID', right_on='supplier_id').head()
# Out:
#    SupplierID                CompanyName       City  supplier_id  ProductID  \
# 0           1             Exotic Liquids     London            1          1
# 1           1             Exotic Liquids     London            1          2
# 2           3  Grandma Kelly's Homestead  Ann Arbor            3          6
# 3           3  Grandma Kelly's Homestead  Ann Arbor            3          7
# 4           3  Grandma Kelly's Homestead  Ann Arbor            3          8
#
#                        ProductName
# 0                             Chai
# 1                            Chang
# 2     Grandma's Boysenberry Spread
# 3  Uncle Bob's Organic Dried Pears
# 4       Northwoods Cranberry Sauce
